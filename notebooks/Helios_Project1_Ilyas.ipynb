# %%
pip install --no-index tqdm scikit-learn matplotlib tensorflow_gpu seaborn h5netcdf
# Out:
# Ignoring pip: markers 'python_version < "3"' don't match your environment
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/avx, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# ...
# tensorboard 2.0.2 has requirement setuptools>=41.0.0, but you'll have setuptools 40.8.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import sklearn

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path
import h5netcdf

# %%
data_path = Path(r"/project/cq-training-1/project1/data/")
df_dummy_test_catalog = pd.read_pickle(data_path/"dummy_test_catalog.pkl")
df_dummy_test_catalog.shape
# Out:
# (35040, 19)

# %%
df_dummy_test_catalog.head()
# Out:
#                                                              ncdf_path  \
# iso-datetime
# 2015-01-01 00:00:00                                                nan
# 2015-01-01 00:15:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2015-01-01 00:30:00                                                nan
# 2015-01-01 00:45:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2015-01-01 01:00:00  /project/cq-training-1/project1/data/netcdf/GO...
#
#                                                         hdf5_8bit_path  \
# iso-datetime
# 2015-01-01 00:00:00  /project/cq-training-1/project1/data/hdf5v7_8b...
# 2015-01-01 00:15:00  /project/cq-training-1/project1/data/hdf5v7_8b...
# 2015-01-01 00:30:00  /project/cq-training-1/project1/data/hdf5v7_8b...
# 2015-01-01 00:45:00  /project/cq-training-1/project1/data/hdf5v7_8b...
# 2015-01-01 01:00:00  /project/cq-training-1/project1/data/hdf5v7_8b...
#
#                     hdf5_8bit_offset  \
# iso-datetime
# ...

# %%
df_train_catalog = pd.read_pickle(data_path/"catalog.helios.public.20100101-20160101.pkl")
df_train_catalog.shape
# Out:
# (210336, 33)

# %%
for col in df_train_catalog.columns:
    print(col)
# Out:
# ncdf_path
# hdf5_8bit_path
# hdf5_8bit_offset
# hdf5_16bit_path
# hdf5_16bit_offset
# BND_DAYTIME
# BND_CLEARSKY_GHI
# BND_CLOUDINESS
# BND_GHI
# TBL_DAYTIME
# TBL_CLEARSKY_GHI
# TBL_CLOUDINESS
# TBL_GHI
# DRA_DAYTIME
# DRA_CLEARSKY_GHI
# DRA_CLOUDINESS
# DRA_GHI
# FPK_DAYTIME
# FPK_CLEARSKY_GHI
# FPK_CLOUDINESS
# FPK_GHI
# GWN_DAYTIME
# GWN_CLEARSKY_GHI
# GWN_CLOUDINESS
# GWN_GHI
# PSU_DAYTIME
# PSU_CLEARSKY_GHI
# PSU_CLOUDINESS
# PSU_GHI
# SXF_DAYTIME
# SXF_CLEARSKY_GHI
# SXF_CLOUDINESS
# SXF_GHI

# %%
for col in df_train_catalog.columns:
    print(col)
    print(df_train_catalog[col].unique(), '\n')
# Out:
# ncdf_path
# ['nan'
#  '/project/cq-training-1/project1/data/netcdf/GOES2010/GridSat-CONUS.goes13.2010.04.14.1900.v01.nc'
#  '/project/cq-training-1/project1/data/netcdf/GOES2010/GridSat-CONUS.goes13.2010.04.14.1915.v01.nc'
#  ...
#  '/project/cq-training-1/project1/data/netcdf/GOES2015/GridSat-CONUS.goes13.2015.12.31.2315.v01.nc'
#  '/project/cq-training-1/project1/data/netcdf/GOES2015/GridSat-CONUS.goes13.2015.12.31.2330.v01.nc'
#  '/project/cq-training-1/project1/data/netcdf/GOES2015/GridSat-CONUS.goes13.2015.12.31.2345.v01.nc']
#
# hdf5_8bit_path
# ['nan'
#  '/project/cq-training-1/project1/data/hdf5v7_8bit/2010.01.01.0800.h5'
#  '/project/cq-training-1/project1/data/hdf5v7_8bit/2010.01.02.0800.h5' ...
#  '/project/cq-training-1/project1/data/hdf5v7_8bit/2015.12.29.0800.h5'
#  '/project/cq-training-1/project1/data/hdf5v7_8bit/2015.12.30.0800.h5'
#  '/project/cq-training-1/project1/data/hdf5v7_8bit/2015.12.31.0800.h5']
#
# hdf5_8bit_offset
# ...

# %%
len(df_train_catalog)
# Out:
# 210336

# %%
dayValueOnly = df_train_catalog[(df_train_catalog.DRA_DAYTIME==1) |
                                (df_train_catalog.TBL_DAYTIME==1) |
                                (df_train_catalog.BND_DAYTIME==1) |
                                (df_train_catalog.FPK_DAYTIME==1) | 
                                (df_train_catalog.GWN_DAYTIME==1) | 
                                (df_train_catalog.PSU_DAYTIME==1) |
                                (df_train_catalog.SXF_DAYTIME==1)]

# %%
pd.set_option('display.max_columns', 500)
dayValueOnly.head()
# Out:
#                     ncdf_path  \
# iso-datetime
# 2010-01-01 00:00:00       nan
# 2010-01-01 00:15:00       nan
# 2010-01-01 00:30:00       nan
# 2010-01-01 12:45:00       nan
# 2010-01-01 13:00:00       nan
#
#                                                         hdf5_8bit_path  \
# iso-datetime
# 2010-01-01 00:00:00                                                nan
# 2010-01-01 00:15:00                                                nan
# 2010-01-01 00:30:00                                                nan
# 2010-01-01 12:45:00  /project/cq-training-1/project1/data/hdf5v7_8b...
# 2010-01-01 13:00:00  /project/cq-training-1/project1/data/hdf5v7_8b...
#
#                     hdf5_8bit_offset  \
# iso-datetime
# 2010-01-01 00:00:00              NaN
# 2010-01-01 00:15:00              NaN
# 2010-01-01 00:30:00              NaN
# 2010-01-01 12:45:00               19
# 2010-01-01 13:00:00               20
#
#                                                        hdf5_16bit_path  \
# ...
